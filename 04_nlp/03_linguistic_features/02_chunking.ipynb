# %% [markdown]
# <center>
#     <h1>Text Chunking (Shallow Parsing) <h1>
# </center >
# Chunking is the process of extracting phrases (noun phrases, verb phrases, etc.)
# from a sentence using POS tags.
#
# This is a **classical NLP technique**, usually done with rule-based grammars.

# %%
import nltk
from nltk import word_tokenize, pos_tag, RegexpParser

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
sentence = "The quick brown fox jumps over the lazy dog"
tokens = word_tokenize(sentence)
tokens
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
# POS Tagging
pos_tags = pos_tag(tokens)
pos_tags
# Out:
# [('The', 'DT'),
#  ('quick', 'JJ'),
#  ('brown', 'NN'),
#  ('fox', 'NN'),
#  ('jumps', 'VBZ'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('lazy', 'JJ'),
#  ('dog', 'NN')]

# %%
# Define Chunk Grammar (Noun Phrase)
grammar = r"""
NP: {<DT>?<JJ>*<NN|NNS>}   # Noun Phrase
"""
chunk_parser = RegexpParser(grammar)

# %%
# !pip install svgling
# Out:
# Requirement already satisfied: svgling in e:\anaconda\envs\tf\lib\site-packages (0.5.0)
# Requirement already satisfied: svgwrite in e:\anaconda\envs\tf\lib\site-packages (from svgling) (1.4.3)

# %%
# Apply Chunking
chunk_tree = chunk_parser.parse(pos_tags)

# %%
chunk_tree.draw()

# %%
# Extract Chunks Programmatically
grammar_vp = r"""
VP: {<VB.*><NP|PP|CLAUSE>+$}
"""
vp_parser = RegexpParser(grammar_vp)
vp_tree = vp_parser.parse(pos_tags)
vp_tree

# %%
# Verb Phrase (VP) Chunking
grammar_all = r"""
NP: {<DT>?<JJ>*<NN|NNS>}
VP: {<VB.*><DT>?<JJ>*<NN|NNS>}
PP: {<IN><NP>}
"""
parser = RegexpParser(grammar_all)
tree = parser.parse(pos_tags)
tree.draw()

# %%
# Multiple Chunk Rules Together
grammar_all = r"""
NP: {<DT>?<JJ>*<NN|NNS>}
VP: {<VB.*><DT>?<JJ>*<NN|NNS>}
PP: {<IN><NP>}
"""
parser = RegexpParser(grammar_all)
tree = parser.parse(pos_tags)
tree.draw()

# %% [markdown]
# ## Why Chunking?
#
# - Helps in **information extraction**
# - Used in **NER preprocessing**
# - Improves **syntactic understanding**
# - Lightweight & fast (rule-based)
#
# Chunking ≠ Parsing
# Chunking ≠ NER
